# %% [markdown]
# ### Ejercicio 8

# %% [markdown]
# La gráfica seleccionada para el desarrollo de este ejercicio
#  es:![ValentineDay.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ###Critica/Solución
#
#
# *   Critica 1: El corazón en el gráfico no da informacion relevante
#
#     Solución 1: Eliminarlo de la gráfica.
#
# *   Critica 2: Subtítulo con errores grámaticales
#
#     Solución 2: Eliminar el subtitulo de la gráfica. Y agrgar en el titulo que la encuesta es por hombres y mujeres.
#
# *   Critica 3: Cambiar el orden ya que puede mal interpretarse, sugiriendo que debe organizarse por mujer y no por hombre.
#
#     Solución 3: Organizar por numero de participantes totales que votaron a favor de la opción.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/drive/MyDrive/visualizacion_esp/DataValentine.xlsx")

# %%
df.head(12)
# Out:
#                             Point Gender  Percentage
# 0          Show how much you care    Men        0.29
# 1                             Sex    Men        0.25
# 2            To go out for dinner    Men        0.18
# 3              To impress someone    Men        0.14
# 4   To receive gifts from someone    Men        0.07
# 5               To treat yourself    Men        0.04
# 6            To buy someone gifts    Men        0.03
# 7          Show how much you care  Women        0.51
# 8                             Sex  Women        0.08
# 9            To go out for dinner  Women        0.06
# 10             To impress someone  Women        0.03
# 11  To receive gifts from someone  Women        0.06

# %%
df_all = df.groupby(by = "Point", axis = 0, as_index=False).mean()
df_all.head(6)
# Out:
#                            Point  Percentage
# 0                            Sex       0.165
# 1         Show how much you care       0.400
# 2           To buy someone gifts       0.075
# 3           To go out for dinner       0.120
# 4             To impress someone       0.085
# 5  To receive gifts from someone       0.065

# %% [markdown]
# La grafica propuesta es la siguiente:

# %%
plt.figure(figsize=(20, 8))
g1 = sns.barplot(x="Point", y="Percentage", hue="Gender", data=df) 
plt.title('What´s the point of Valentine´s Day for Men and Women?', fontsize = 20)  
g1.set(xlabel=None)
plt.show()
